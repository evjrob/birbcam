# %%
from fastai.vision.all import *
from PIL import Image
import numpy as np
import cv2 as cv
import os
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
#defaults.device = torch.device('cpu')
learn = load_learner('../models/birbcam_prod.pkl')

# %%
tst_files = os.listdir('../imgs/')
tst_files = tst_files
tst_files = [t for t in tst_files if '2020-12-20T11:38:46' in str(t)]

# %%
f = tst_files[0]
img = np.asarray(Image.open(f'../imgs/{f}'))
print(f)
pred = learn.predict(f'../imgs/{f}')
print(pred)
plt.imshow(img)
# Out:
# 2020-12-20T11:38:46_none.jpg
# (['chickadee'], tensor([ True, False, False, False]), tensor([0.6248, 0.0025, 0.3030, 0.0319]))

# %%
learn.dls.vocab
